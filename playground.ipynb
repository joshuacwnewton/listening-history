# %%
import pandas as pd    # DataFrame manipulation
import snapy as sp     # Near-duplicate detection (to help correcti similarly-tagged listens)
import pylistenbrainz  # Wrapper for ListenBrainz's Web API for uploading listens

# %%
path_tsv_2009_2014 = "listens/export-2009-2014/data/scrobbles.tsv"
df_old = pd.read_csv(path_tsv_2009_2014, sep='\t', header=0)
df_old["DateTime"] = pd.to_datetime(df_old['unixtime'], unit='s')
df_old.set_index("DateTime", inplace=True)
df_old.drop(["unixtime", "ISO time", "track mbid", "artist mbid", "uncorrected track name", 
             "uncorrected track mbid", "uncorrected artist name", "uncorrected artist mbid", "album mbid", 
             "album artist name", "album artist mbid", "application"], axis="columns", inplace=True)

path_csv_2014_2017 = "listens/scrobbles-2014-2017.csv" 
df_new = pd.read_csv(path_csv_2014_2017, names=["artist name", "album name", "track name", "DateTime"])
df_new["DateTime"] = pd.to_datetime(df_new["DateTime"])
df_new.set_index("DateTime", inplace=True)

path_csv_2018_2020 = "listens/scrobbles-2018-2020.csv" 
df_newest = pd.read_csv(path_csv_2018_2020, names=["artist name", "album name", "track name", "DateTime"])
df_newest["DateTime"] = pd.to_datetime(df_newest["DateTime"])
df_newest.set_index("DateTime", inplace=True)
df_newest.tail()

df_listens = pd.concat([df_old, df_new, df_newest])

# %%
print(df_listens["track name"].value_counts().head(50))
print()
print(df_listens["album name"].value_counts().head(50))
print()
print(df_listens["artist name"].value_counts().head(50))
# Out:
# Satellite Mind                                         154
# Ghost                                                  147
# Brielle                                                142
# Milk & Honey                                           122
# Fireflies                                              117
# Crazy for You                                          110
# Implosionatic                                          107
# Dear Vienna                                            105
# Tessellate                                             105
# Concerning the UFO Sighting Near Highland, Illinois    103
# Wild West                                               97
# Butterfly Wings                                         93
# Oats We Sow                                             91
# In the Aeroplane Over the Sea                           90
# Starring                                                89
# Fireworks                                               87
# You Do It to Me and I Do It to You Too                  87
# Brother Sport                                           86
# Black Day in December                                   86
# Wasted Daylight                                         85
# Two Weeks                                               79
# Juno                                                    78
# Dear Elkhorn                                            78
# Intro                                                   78
# Perth                                                   74
# Decatur, or, Round of Applause for Your Stepmother!     72
# The State I Am In                                       72
# Emerald Lake, AB                                        72
# Lake Michigan                                           70
# Evening/Morning                                         69
# Voice Like a Bell                                       69
# Stanley Kubrick                                         68
# Rainbow Veins                                           67
# Sleeping States                                         66
# If You're Feeling Sinister                              64
# Casimir Pulaski Day                                     64
# John Wayne Gacy, Jr.                                    63
# Camilo (The Magician)                                   62
# B.C. Orienteering                                       61
# Ghosting                                                61
# Luna                                                    61
# Listen to the Math                                      61
# False Creek Change                                      60
# Holocene                                                60
# A Lack of Color                                         60
# Gentleman                                               59
# Hannah                                                  58
# Your English Is Good                                    57
# Strawberry Avalanche                                    57
# Out On the Shield                                       56
# Name: track name, dtype: int64
#
# Islands Disappear                                                         787
# Illinoise                                                                 641
# An Airplane Carried Me To Bed                                             591
# Weathervanes                                                              579
# 69 Love Songs                                                             560
# Elephant Shell                                                            525
# Moenie and Kitchi                                                         491
# Maybe I'm Dreaming                                                        462
# The Five Ghosts                                                           451
# Ocean Eyes (Deluxe Edition)                                               425
# James Blake                                                               412
# Merriweather Post Pavilion                                                399
# Fantasies                                                                 395
# Carnavas                                                                  374
# Writing of Blues and Yellows (Deluxe Version)                             365
# Friendly Fires                                                            348
# Transatlanticism                                                          346
# In Your Dreams                                                            324
# Carrie & Lowell                                                           320
# Dark Arc                                                                  306
# In the Aeroplane Over the Sea                                             303
# Narrow Stairs                                                             284
# Swoon                                                                     278
# Champ                                                                     277
# Contra                                                                    275
# Boxer                                                                     273
# The Moon Rang Like a Bell                                                 270
# Kill Them with Kindness                                                   267
# Future Breeds                                                             264
# Gorilla Manor                                                             264
# Bon Iver                                                                  264
# I Like It When You Sleep For You Are So Beautiful Yet So Unaware Of It    264
# Give Up                                                                   260
# Veckatimest                                                               258
# Punisher                                                                  258
# Intuit                                                                    253
# Say I Am You                                                              250
# O My Heart                                                                249
# Old World Underground, Where Are You Now?                                 247
# Crazy for You                                                             242
# Capacity                                                                  240
# Set Yourself on Fire                                                      233
# Emergency & I                                                             230
# To Pimp a Butterfly                                                       230
# Avi Buffalo                                                               227
# Sainthood                                                                 226
# Plans                                                                     221
# If You're Feeling Sinister: Live At The Barbican (September 25)           211
# Since I Left You                                                          210
# Because the Internet                                                      210
# Name: album name, dtype: int64
#
# Sufjan Stevens              2230
# Gregory and the Hawk        1524
# Animal Collective           1502
# Stars                       1460
# Owl City                    1401
# Death Cab for Cutie         1314
# Metric                      1124
# Tokyo Police Club            982
# Said The Whale               851
# Bon Iver                     832
# Belle and Sebastian          821
# Silversun Pickups            740
# Vampire Weekend              725
# The National                 645
# The Magnetic Fields          637
# Freelance Whales             631
# Kendrick Lamar               611
# Sky Sailing                  591
# Mother Mother                578
# James Blake                  550
# Billie Marten                548
# Tegan and Sara               527
# Saintseneca                  488
# The Weepies                  483
# Friendly Fires               482
# Headlights                   453
# Local Natives                442
# Beach House                  433
# Avi Buffalo                  426
# M83                          415
# Radiohead                    409
# Tame Impala                  376
# The Postal Service           370
# Paramore                     366
# Said the Whale               365
# All Time Low                 363
# Grizzly Bear                 356
# The 1975                     340
# Fleet Foxes                  333
# Phoebe Bridgers              321
# Neutral Milk Hotel           321
# Wilsen                       315
# Bombay Bicycle Club          315
# Ramona Falls                 313
# The Tallest Man on Earth     309
# Hot Hot Heat                 304
# Hundred Waters               302
# The Radio Dept.              299
# Big Thief                    298
# Motion City Soundtrack       292
# Name: artist name, dtype: int64

# %%
print(df_listens["artist name"].str.count("Phoebe Bridgers").sum())
# Out:
# 351

# %%
df_listens.to_csv("listens/scrobbles-merged-2009-2020.csv")
